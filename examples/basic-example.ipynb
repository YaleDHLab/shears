# %%
# ensure imports aren't cached
# %load_ext autoreload
# %autoreload 2

# show plots in notebook
# %matplotlib inline

# %%
from scipy.ndimage import imread
import matplotlib.pyplot as plt
import glob

# identify the images to process
input_images = glob.glob('../sample-data/pharos/*.jpg')

# show the first page scan
im = plt.imread(input_images[0])
plt.imshow(im)

# %%
import sys
[sys.path.append(i) for i in ['.', '..', '../src']]
from src import extract

# crop out the pictoral content in the page scan
cropped = extract.extract_image(im)

# show the cropped illustration
plt.imshow(cropped)
plt.show()
