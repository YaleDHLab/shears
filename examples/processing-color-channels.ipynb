# %%
# ensure imports aren't cached
# %load_ext autoreload
# %autoreload 2

# show plots in notebook
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import sys, glob
[sys.path.append(i) for i in ['.', '..', '../picsnip']]
import picsnip

# identify the images to process
input_images = glob.glob('../sample-data/pharos/*.jpg')

# show the first page scan
picsnip.plot_image(input_images[0])

# %%
for i in input_images:
  cropped = picsnip.crop_with_color_diffs(i, plot=True)
  picsnip.plot_image(cropped, 'Extracted Image')
