# %%
# ensure imports aren't cached
# %load_ext autoreload
# %autoreload 2

# show plots in notebook
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import glob, sys
[sys.path.append(i) for i in ['.', '..', '../src']]
from src import extract

# identify the images to process
input_images = glob.glob('../sample-data/hathi/*.jpg')

# process each image
for i in input_images:
  
  # show the full page scan
  extract.plot_image(i, 'Page Scan')
  
  # use the filter parameters to pull out the illustration on a page
  result = extract.extract_image(i,
                                  filter_min_size=900,
                                  filter_threshold=0.8,
                                  filter_connectivity=1,
                                  plot=False)

  # show the extracted illustration
  extract.plot_image(result, 'Extracted Image')
